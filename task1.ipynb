# %% [markdown]
# Task 1: Vectorized Multi-Layer Perceptron (MLP)

# %%
import numpy as np

# %% [markdown]
# Input Data (Batch of Samples)

# %%
X = np.array([[1, 2],
              [3, 4],
              [5, 6]])

# One-Hot Target Labels
Y = np.array([[1, 0],
              [0, 1],
              [1, 0]])

# %% [markdown]
# Initialize Parameters

# %%
np.random.seed(42)

W1 = np.random.randn(2, 3)
b1 = np.zeros((1, 3))

W2 = np.random.randn(3, 2)
b2 = np.zeros((1, 2))

learning_rate = 0.01
epochs = 100

# %% [markdown]
# Activation Functions

# %%
def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return (x > 0).astype(float)

def softmax(x):
    exp = np.exp(x - np.max(x, axis=1, keepdims=True))
    return exp / np.sum(exp, axis=1, keepdims=True)

# %% [markdown]
# Training

# %%
for epoch in range(epochs):
    # Forward pass
    Z1 = np.dot(X, W1) + b1
    A1 = relu(Z1)
    Z2 = np.dot(A1, W2) + b2
    A2 = softmax(Z2)

    # Compute loss (Cross-Entropy)
    loss = -np.sum(Y * np.log(A2 + 1e-9)) / len(X)

    # Backward pass
    dZ2 = A2 - Y
    dW2 = np.dot(A1.T, dZ2)
    db2 = np.sum(dZ2, axis=0, keepdims=True)

    dA1 = np.dot(dZ2, W2.T)
    dZ1 = dA1 * relu_derivative(Z1)
    dW1 = np.dot(X.T, dZ1)
    db1 = np.sum(dZ1, axis=0, keepdims=True)

    # Update parameters
    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss:.4f}")
# Out:
# Epoch 0, Loss: 2.0715
# Epoch 10, Loss: 0.6458
# Epoch 20, Loss: 0.6452
# Epoch 30, Loss: 0.6447
# Epoch 40, Loss: 0.6443
# Epoch 50, Loss: 0.6438
# Epoch 60, Loss: 0.6434
# Epoch 70, Loss: 0.6430
# Epoch 80, Loss: 0.6426
# Epoch 90, Loss: 0.6423

# %% [markdown]
#  Final Prediction

# %%
print("\nFinal Loss:", loss)

print("\nPredicted Output:")
print(A2)

print("\nPredicted Class:")
print(np.argmax(A2, axis=1))
# Out:
# Final Loss: 0.6419786141555024
#
# Predicted Output:
# [[0.58946664 0.41053336]
#  [0.64810301 0.35189699]
#  [0.70258989 0.29741011]]
#
# Predicted Class:
# [0 0 0]
